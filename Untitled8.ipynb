# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhanushree192003/Adani-stock-analysis/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fe922600-8b62-4674-be8d-357de51b5190" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fe922600-8b62-4674-be8d-357de51b5190">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

file_path = "/content/Adani1 (1).csv"  # File is stored here in Colab
df = pd.read_csv(file_path)

# Display the first few rows
df.head()
# Out:
#         Date   Price    Open    High     Low   Volume
# 0  01-Sep-22  408.50  417.00  418.85  400.05  5302707
# 1  02-Sep-22  401.25  413.35  415.00  400.00  2852897
# 2  05-Sep-22  389.85  403.65  407.00  385.55  3344426
# 3  06-Sep-22  407.75  392.00  409.30  386.00  3907288
# 4  07-Sep-22  406.30  404.70  415.75  401.25  2901689

# %%
df.columns
# Out:
# Index(['Date', 'Price', 'Open', 'High', 'Low', 'Volume'], dtype='object')

# %%
df.isnull().sum()
# Out:
# Date      0
# Price     0
# Open      0
# High      0
# Low       0
# Volume    0
# dtype: int64

# %%
df.dtypes
# Out:
# Date       object
# Price     float64
# Open      float64
# High      float64
# Low       float64
# Volume      int64
# dtype: object

# %%
import matplotlib.pyplot as plt

column_name = "Price"  # Replace with an actual column name
df[column_name].hist(bins=30, edgecolor="black")

plt.xlabel(column_name)
plt.ylabel("Frequency")
plt.title(f"Histogram of {column_name}")
plt.show()

# %%
import seaborn as sns

x_col = "Open"  # Replace with actual column name
y_col = "Price"  # Replace with actual column name

sns.scatterplot(x=df[x_col], y=df[y_col])
plt.xlabel(x_col)
plt.ylabel(y_col)
plt.title(f"Scatter Plot: {x_col} vs {y_col}")
plt.show()

# %%
sns.boxplot(y=df["Volume"])  # Replace "Volume" with your column
plt.title("Box Plot of Volume")
plt.show()

# %% [markdown]
# # New Section

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
df["MA50"] = df["Price"].rolling(window=50).mean()
df["MA200"] = df["Price"].rolling(window=200).mean()

plt.figure(figsize=(12, 6))
plt.plot(df["Price"], label="Price", color="blue")
plt.plot(df["MA50"], label="50-Day MA", color="red")
plt.plot(df["MA200"], label="200-Day MA", color="green")
plt.xlabel("Date")
plt.ylabel("Price")
plt.title("Stock Price with Moving Averages")
plt.legend()
plt.show()

# %%
def calculate_rsi(data, window=14):
    delta = data.diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=window).mean()
    rs = gain / loss
    return 100 - (100 / (1 + rs))

df["RSI"] = calculate_rsi(df["Price"])

plt.figure(figsize=(12, 6))
plt.plot(df["RSI"], label="RSI", color="orange")
plt.axhline(70, linestyle="--", color="red")  # Overbought
plt.axhline(30, linestyle="--", color="green")  # Oversold
plt.xlabel("Date")
plt.ylabel("RSI")
plt.title("Relative Strength Index (RSI)")
plt.legend()
plt.show()
